# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Anjani Upadhyay**

# %% [markdown]
# Second Year Student

# %% [markdown]
# *I am interested in data science because I'm really passionate about working with machine learning as well as artificial intelligence and learning more about recommendation engines, face recognition and other such features.*

# %% [markdown]
# ### My code in cell 5 is supposed to print the message Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
#  - one
#  - two
#  - three
#
#  ***
#
# 1. one
# 1. two
# 1. three
